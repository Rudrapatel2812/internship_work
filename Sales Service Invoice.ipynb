# %%
import csv
import json
import pandas as pd
from datetime import datetime

customerName = {}
with open('/Users/patelrudra/Documents/Medkart/wms/Contacts.csv', mode ='r')as file:
    masterFile = csv.reader(file)    
    for vendor in masterFile:
        customerName[vendor[1]] = vendor[0]
        
# vendorItem = {}
# with open('/Users/patelrudra/Documents/BOOKS/Item.csv', mode ='r')as file1:
#     masterFile = csv.reader(file1)    
#     for vendor in masterFile:
#         vendorItem[vendor[1]] = vendor[0]
        
with open('/Users/patelrudra/Documents/Medkart/wms/sales sevice invoice.csv', mode ='r')as file:

    csvFile = csv.reader(file)
    data_list = []
    null_voucher_dict = []
    data={}
    count=0
    Bill=True
    notItems=[]
    
    for entry in csvFile:
            data['line_items'] = data_list
            null_voucher_dict.append(data)
            data_list=[]
            date_object = datetime.strptime(entry[0],"%d-%b-%y")
            formatted_date = date_object.strftime("%Y-%m-%d")
            replaced_num=entry[4].replace("_","-")
            data = {
                'date': formatted_date,
                'customer_id': customerName[entry[1]],
                'invoice_number': replaced_num,
                'source_of_supply':"24",
                 "adjustment" : entry[17],
                "is_inclusive_tax": False,
                
             }
            data1 = {
                'item_id':"1357403000004979569",
                'rate':entry[14],
                "quantity":"1",
                "item_order":len(data_list)+1
             }
            data_list.append(data1)
    for data in null_voucher_dict:
        json_data = json.dumps(data, indent=4)
        with open("sales.json", "a") as outfile:
            outfile.write(json_data + '\n')

# %%
null_voucher_dict.pop(0)
null_voucher_dict
# Out:
# [{'date': '2023-05-01',
#   'customer_id': '1357403000004221721',
#   'invoice_number': 'SSI01',
#   'source_of_supply': '24',
#   'adjustment': '0.32',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '576.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-01',
#   'customer_id': '1357403000004222342',
#   'invoice_number': 'SSI02',
#   'source_of_supply': '24',
#   'adjustment': '-0.32',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '27224.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-01',
#   'customer_id': '1357403000004222801',
#   'invoice_number': 'SSI03',
#   'source_of_supply': '24',
#   'adjustment': '-0.22',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '26779.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-01',
#   'customer_id': '1357403000004222423',
#   'invoice_number': 'SSI04',
#   'source_of_supply': '24',
#   'adjustment': '0.04',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '22122.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-01',
#   'customer_id': '1357403000004222828',
#   'invoice_number': 'SSI05',
#   'source_of_supply': '24',
#   'adjustment': '0.48',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '15514.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-01',
#   'customer_id': '1357403000004222045',
#   'invoice_number': 'SSI06',
#   'source_of_supply': '24',
#   'adjustment': '',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '13950.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-01',
#   'customer_id': '1357403000004222396',
#   'invoice_number': 'SSI07',
#   'source_of_supply': '24',
#   'adjustment': '-0.28',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '13546.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-01',
#   'customer_id': '1357403000004222909',
#   'invoice_number': 'SSI08',
#   'source_of_supply': '24',
#   'adjustment': '-0.32',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '9724.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-01',
#   'customer_id': '1357403000004222612',
#   'invoice_number': 'SSI09',
#   'source_of_supply': '24',
#   'adjustment': '0.20',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '9560.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-01',
#   'customer_id': '1357403000004222936',
#   'invoice_number': 'SSI10',
#   'source_of_supply': '24',
#   'adjustment': '0.42',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '7031.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-01',
#   'customer_id': '1357403000004221829',
#   'invoice_number': 'SSI11',
#   'source_of_supply': '24',
#   'adjustment': '0.50',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '6575.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-01',
#   'customer_id': '1357403000004221667',
#   'invoice_number': 'SSI12',
#   'source_of_supply': '24',
#   'adjustment': '-0.08',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '5306.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-01',
#   'customer_id': '1357403000004222369',
#   'invoice_number': 'SSI13',
#   'source_of_supply': '24',
#   'adjustment': '0.34',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '5137.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-01',
#   'customer_id': '1357403000004222882',
#   'invoice_number': 'SSI14',
#   'source_of_supply': '24',
#   'adjustment': '0.10',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '4405.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-01',
#   'customer_id': '1357403000004222666',
#   'invoice_number': 'SSI15',
#   'source_of_supply': '24',
#   'adjustment': '0.24',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '3732.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-01',
#   'customer_id': '1357403000004221613',
#   'invoice_number': 'SSI16',
#   'source_of_supply': '24',
#   'adjustment': '0.06',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '3433.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-01',
#   'customer_id': '1357403000004222261',
#   'invoice_number': 'SSI17',
#   'source_of_supply': '24',
#   'adjustment': '-0.16',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '3412.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-01',
#   'customer_id': '1357403000004221991',
#   'invoice_number': 'SSI18',
#   'source_of_supply': '24',
#   'adjustment': '0.06',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '3233.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-01',
#   'customer_id': '1357403000004222288',
#   'invoice_number': 'SSI19',
#   'source_of_supply': '24',
#   'adjustment': '-0.24',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '3218.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-01',
#   'customer_id': '1357403000004222315',
#   'invoice_number': 'SSI20',
#   'source_of_supply': '24',
#   'adjustment': '-0.12',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '3084.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-01',
#   'customer_id': '1357403000004221883',
#   'invoice_number': 'SSI21',
#   'source_of_supply': '24',
#   'adjustment': '0.26',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '3043.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-01',
#   'customer_id': '1357403000004222099',
#   'invoice_number': 'SSI22',
#   'source_of_supply': '24',
#   'adjustment': '-0.14',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '2923.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-01',
#   'customer_id': '1357403000004221964',
#   'invoice_number': 'SSI23',
#   'source_of_supply': '24',
#   'adjustment': '0.16',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '2438.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-01',
#   'customer_id': '1357403000004221802',
#   'invoice_number': 'SSI24',
#   'source_of_supply': '24',
#   'adjustment': '-0.22',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '2229.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-01',
#   'customer_id': '1357403000004222450',
#   'invoice_number': 'SSI25',
#   'source_of_supply': '24',
#   'adjustment': '-0.44',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '2058.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-01',
#   'customer_id': '1357403000004222747',
#   'invoice_number': 'SSI26',
#   'source_of_supply': '24',
#   'adjustment': '0.18',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '1899.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-01',
#   'customer_id': '1357403000004221586',
#   'invoice_number': 'SSI27',
#   'source_of_supply': '24',
#   'adjustment': '0.26',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '1543.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-01',
#   'customer_id': '1357403000004222639',
#   'invoice_number': 'SSI28',
#   'source_of_supply': '24',
#   'adjustment': '-0.32',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '1424.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-01',
#   'customer_id': '1357403000004222072',
#   'invoice_number': 'SSI29',
#   'source_of_supply': '24',
#   'adjustment': '0.20',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '1110.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-01',
#   'customer_id': '1357403000004221559',
#   'invoice_number': 'SSI30',
#   'source_of_supply': '24',
#   'adjustment': '0.36',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '1098.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-01',
#   'customer_id': '1357403000004222180',
#   'invoice_number': 'SSI31',
#   'source_of_supply': '24',
#   'adjustment': '-0.48',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '986.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-01',
#   'customer_id': '1357403000004222477',
#   'invoice_number': 'SSI32',
#   'source_of_supply': '24',
#   'adjustment': '0.10',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '855.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-01',
#   'customer_id': '1357403000004222234',
#   'invoice_number': 'SSI33',
#   'source_of_supply': '24',
#   'adjustment': '0.16',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '838.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-01',
#   'customer_id': '1357403000004223245',
#   'invoice_number': 'SSI34',
#   'source_of_supply': '24',
#   'adjustment': '-0.48',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '636.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-01',
#   'customer_id': '1357403000004222774',
#   'invoice_number': 'SSI35',
#   'source_of_supply': '24',
#   'adjustment': '0.32',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '626.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-02',
#   'customer_id': '1357403000004221775',
#   'invoice_number': 'SSI36',
#   'source_of_supply': '24',
#   'adjustment': '-0.02',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '5068.02',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-02',
#   'customer_id': '1357403000004221586',
#   'invoice_number': 'SSI37',
#   'source_of_supply': '24',
#   'adjustment': '-0.20',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '1190.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-02',
#   'customer_id': '1357403000004221802',
#   'invoice_number': 'SSI38',
#   'source_of_supply': '24',
#   'adjustment': '-0.30',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '699.40',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-02',
#   'customer_id': '1357403000004221829',
#   'invoice_number': 'SSI39',
#   'source_of_supply': '24',
#   'adjustment': '0.08',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '3058.40',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-02',
#   'customer_id': '1357403000004221883',
#   'invoice_number': 'SSI40',
#   'source_of_supply': '24',
#   'adjustment': '-0.42',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '2283.40',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-02',
#   'customer_id': '1357403000004221964',
#   'invoice_number': 'SSI41',
#   'source_of_supply': '24',
#   'adjustment': '-0.40',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '1362.20',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-02',
#   'customer_id': '1357403000004221991',
#   'invoice_number': 'SSI42',
#   'source_of_supply': '24',
#   'adjustment': '0.18',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '2199.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-02',
#   'customer_id': '1357403000004222234',
#   'invoice_number': 'SSI43',
#   'source_of_supply': '24',
#   'adjustment': '0.38',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '991.20',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-02',
#   'customer_id': '1357403000004222261',
#   'invoice_number': 'SSI44',
#   'source_of_supply': '24',
#   'adjustment': '0.22',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '1721.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-02',
#   'customer_id': '1357403000004222288',
#   'invoice_number': 'SSI45',
#   'source_of_supply': '24',
#   'adjustment': '-0.44',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '1722.40',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-02',
#   'customer_id': '1357403000004222531',
#   'invoice_number': 'SSI46',
#   'source_of_supply': '24',
#   'adjustment': '-0.22',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '1429.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-02',
#   'customer_id': '1357403000004222666',
#   'invoice_number': 'SSI47',
#   'source_of_supply': '24',
#   'adjustment': '-0.40',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '2115.60',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-02',
#   'customer_id': '1357403000004222801',
#   'invoice_number': 'SSI48',
#   'source_of_supply': '24',
#   'adjustment': '0.26',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '8228.60',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-02',
#   'customer_id': '1357403000004222828',
#   'invoice_number': 'SSI49',
#   'source_of_supply': '24',
#   'adjustment': '0.14',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '6077.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-02',
#   'customer_id': '1357403000004222882',
#   'invoice_number': 'SSI50',
#   'source_of_supply': '24',
#   'adjustment': '-0.02',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '2039.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-02',
#   'customer_id': '1357403000004221721',
#   'invoice_number': 'SSI51',
#   'source_of_supply': '24',
#   'adjustment': '-0.22',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '679.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-02',
#   'customer_id': '1357403000004222774',
#   'invoice_number': 'SSI52',
#   'source_of_supply': '24',
#   'adjustment': '0.42',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '1031.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-02',
#   'customer_id': '1357403000004222369',
#   'invoice_number': 'SSI53',
#   'source_of_supply': '24',
#   'adjustment': '0.12',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '2916.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-02',
#   'customer_id': '1357403000004222342',
#   'invoice_number': 'SSI54',
#   'source_of_supply': '24',
#   'adjustment': '0.38',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '10109.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-02',
#   'customer_id': '1357403000004222396',
#   'invoice_number': 'SSI55',
#   'source_of_supply': '24',
#   'adjustment': '0.24',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '5232.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-02',
#   'customer_id': '1357403000004222423',
#   'invoice_number': 'SSI56',
#   'source_of_supply': '24',
#   'adjustment': '0.36',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '9348.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-02',
#   'customer_id': '1357403000004222045',
#   'invoice_number': 'SSI57',
#   'source_of_supply': '24',
#   'adjustment': '0.20',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '4810.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-02',
#   'customer_id': '1357403000004222612',
#   'invoice_number': 'SSI58',
#   'source_of_supply': '24',
#   'adjustment': '-0.44',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '4858.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-02',
#   'customer_id': '1357403000004222072',
#   'invoice_number': 'SSI59',
#   'source_of_supply': '24',
#   'adjustment': '0.20',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '610.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-02',
#   'customer_id': '1357403000004221613',
#   'invoice_number': 'SSI60',
#   'source_of_supply': '24',
#   'adjustment': '0.30',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '2165.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-02',
#   'customer_id': '1357403000004222747',
#   'invoice_number': 'SSI61',
#   'source_of_supply': '24',
#   'adjustment': '-0.34',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '563.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-02',
#   'customer_id': '1357403000004222180',
#   'invoice_number': 'SSI62',
#   'source_of_supply': '24',
#   'adjustment': '0.32',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '926.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-02',
#   'customer_id': '1357403000004223245',
#   'invoice_number': 'SSI63',
#   'source_of_supply': '24',
#   'adjustment': '-0.24',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '418.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-02',
#   'customer_id': '1357403000004222477',
#   'invoice_number': 'SSI64',
#   'source_of_supply': '24',
#   'adjustment': '-0.02',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '589.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-02',
#   'customer_id': '1357403000004222639',
#   'invoice_number': 'SSI65',
#   'source_of_supply': '24',
#   'adjustment': '-0.02',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '3039.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-06',
#   'customer_id': '1357403000004223245',
#   'invoice_number': 'SSI66',
#   'source_of_supply': '24',
#   'adjustment': '',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '15000.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-05-29',
#   'customer_id': '1357403000004190640',
#   'invoice_number': 'SSI67',
#   'source_of_supply': '24',
#   'adjustment': '',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '115000.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-04-04',
#   'customer_id': '1357403000004222045',
#   'invoice_number': 'SSI68',
#   'source_of_supply': '24',
#   'adjustment': '0.40',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '1920.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-04-04',
#   'customer_id': '1357403000004222612',
#   'invoice_number': 'SSI69',
#   'source_of_supply': '24',
#   'adjustment': '-0.40',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '1280.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-04-11',
#   'customer_id': '1357403000004222531',
#   'invoice_number': 'SSI70',
#   'source_of_supply': '24',
#   'adjustment': '',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '25000.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-04-12',
#   'customer_id': '1357403000004222558',
#   'invoice_number': 'SSI71',
#   'source_of_supply': '24',
#   'adjustment': '-0.02',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '289.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-04-13',
#   'customer_id': '1357403000004222612',
#   'invoice_number': 'SSI72',
#   'source_of_supply': '24',
#   'adjustment': '',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '1800.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-04-13',
#   'customer_id': '1357403000004222045',
#   'invoice_number': 'SSI73',
#   'source_of_supply': '24',
#   'adjustment': '',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '1800.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-04-17',
#   'customer_id': '1357403000004222801',
#   'invoice_number': 'SSI74',
#   'source_of_supply': '24',
#   'adjustment': '',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '1920.00',
#     'quantity': '1',
#     'item_order': 1}]},
#  {'date': '2023-04-17',
#   'customer_id': '1357403000004222828',
#   'invoice_number': 'SSI75',
#   'source_of_supply': '24',
#   'adjustment': '',
#   'is_inclusive_tax': False,
#   'line_items': [{'item_id': '1357403000004979569',
#     'rate': '1920.00',
#     'quantity': '1',
#     'item_order': 1}]}]

# %%
import requests
import json
url = "https://www.zohoapis.in/books/v3/invoices?ignore_auto_number_generation=true&organization_id=60022053195"
headers = {
  'Content-Type': 'application/json',
  'Authorization': 'Zoho-oauthtoken 1000.92ee054e61fa2d8cdad4b2c49881bf60.3e74b4b4f24f5d5c9bc813e0c1fa698a'
}
failedData = []
for data in null_voucher_dict:
    payload = json.dumps(data)

    response = requests.request("POST", url, headers=headers, data=payload)
    if response.status_code >= 200 and response.status_code < 300:  # Assuming a successful response has a status code of 200
        data = response.json()
#         invoiceID = data['invoice']['invoice_id']
#         response = requests.request("POST", f"https://www.zohoapis.in/books/v3/invoices/{invoiceID}/status/sent?organization_id=60021182160", headers=headers, data=[])
    else:

        print(f"API request failed with status code {response.status_code}")
        response_content = response.content.decode('utf-8')
        failedData.append(data['invoice_number'])
        print(response_content)

print("__________________________________")
print("Finished")
print("__________________________________")
print("failed records bill number : ")
print(failedData)
# Out:
# __________________________________
# Finished
# __________________________________
# failed records bill number :
# []
