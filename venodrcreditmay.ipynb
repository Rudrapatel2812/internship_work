# %%
import csv
import json
import pandas as pd
from datetime import datetime

vendorMaster = {}
with open('/Users/patelrudra/Documents/BOOKS/VendorsMaster.csv', mode ='r')as file:
    masterFile = csv.reader(file)    
    for vendor in masterFile:
        vendorMaster[vendor[1]] = vendor[0]
        
vendorItem = {}
with open('/Users/patelrudra/Documents/BOOKS/Item.csv', mode ='r')as file1:
    masterFile = csv.reader(file1)    
    for vendor in masterFile:
        vendorItem[vendor[1]] = vendor[0]
        
gstConfigurationData = {
    "0" : "1357403000000016427",
    "5" : "1357403000000016433",
    "12" : "1357403000000016439",
    "18" : "1357403000000016445",
    "28" : "1357403000000016451"
}
        
with open('/Users/patelrudra/Documents/Medkart/wms/venodrcreditmay.csv', mode ='r')as file:

    csvFile = csv.reader(file)
    data_list = []
    null_voucher_dict = []
    data={}
    count=0
    Bill=True
    notItems=[]
    
    for entry in csvFile:
        if entry[2] == '':
            if entry[1] == 'Grand Total':
                continue;
#             if entry[1] not in vendorItem:
#                 notItems.append(entry[1])
#                 continue
            data1 = {
                'item_id': vendorItem[entry[1]],
                'rate':entry[12],
                "itc_eligibility":"eligible",
                "quantity":"1",
                "item_order":len(data_list)+1,
               "tax_id" : gstConfigurationData[entry[1].split("_")[1]]
             }
            
            data_list.append(data1)
        else:
            data['line_items'] = data_list
            null_voucher_dict.append(data)
            data_list=[]
            date_object = datetime.strptime(entry[0], "%d-%b-%y")
            formatted_date = date_object.strftime("%Y-%m-%d")

            data = {
                'date': formatted_date,
                'vendor_id': vendorMaster[entry[1]],
                "vendor_credit_number" : entry[2],
                  "tax_override": False,
                "gst_no":entry[3],
                "is_inclusive_tax": False,
                 "reference_invoice_type":"registered",
                "reference_number":entry[3]
             }
            
    for data in null_voucher_dict:
        json_data = json.dumps(data, indent=4)
        with open("sample.json", "a") as outfile:
            outfile.write(json_data + '\n')

# %%
null_voucher_dict.pop(0)
null_voucher_dict
# Out:
# [{'date': '2023-05-01',
#   'vendor_id': '1357403000004097389',
#   'vendor_credit_number': '230HO1PR00000107',
#   'tax_override': False,
#   'gst_no': '24AHNPB6309B1ZV',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': 'TD02718',
#   'line_items': [{'item_id': '1357403000004358245',
#     'rate': '462.85',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016439'}]},
#  {'date': '2023-05-01',
#   'vendor_id': '1357403000004185325',
#   'vendor_credit_number': '230HO1PR00000106',
#   'tax_override': False,
#   'gst_no': '24AAJCV1878M1ZP',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': '23SZ010237',
#   'line_items': [{'item_id': '1357403000004360018',
#     'rate': '342.78',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016439'}]},
#  {'date': '2023-05-01',
#   'vendor_id': '1357403000004107568',
#   'vendor_credit_number': '230HO1PR00000105',
#   'tax_override': False,
#   'gst_no': '24AAICG1606M1ZN',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': 'GR22242',
#   'line_items': [{'item_id': '1357403000004359397',
#     'rate': '950.00',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016439'},
#    {'item_id': '1357403000004359397',
#     'rate': '4750.00',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 2,
#     'tax_id': '1357403000000016439'}]},
#  {'date': '2023-05-01',
#   'vendor_id': '1357403000004161727',
#   'vendor_credit_number': '230HO1PR00000104',
#   'tax_override': False,
#   'gst_no': '24AAWFS8806J1ZH',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': '23SZ013695',
#   'line_items': [{'item_id': '1357403000004360315',
#     'rate': '3983.51',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016439'}]},
#  {'date': '2023-05-01',
#   'vendor_id': '1357403000004121166',
#   'vendor_credit_number': '230HO1PR00000103',
#   'tax_override': False,
#   'gst_no': '24AAAFK9583A1ZI',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': 'PK73969',
#   'line_items': [{'item_id': '1357403000004358326',
#     'rate': '247.02',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359100',
#     'rate': '111.45',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 2,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359964',
#     'rate': '680.26',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 3,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360009',
#     'rate': '1360.80',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 4,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360009',
#     'rate': '38.81',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 5,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '1521.42',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 6,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '345.00',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 7,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '211.71',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 8,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '54.78',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 9,
#     'tax_id': '1357403000000016427'}]},
#  {'date': '2023-05-01',
#   'vendor_id': '1357403000004117791',
#   'vendor_credit_number': '230HO1PR00000102',
#   'tax_override': False,
#   'gst_no': '24AACFR8019A1ZO',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': 'PK81450',
#   'line_items': [{'item_id': '1357403000004359496',
#     'rate': '95.22',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '24.72',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 2,
#     'tax_id': '1357403000000016427'}]},
#  {'date': '2023-05-01',
#   'vendor_id': '1357403000004116117',
#   'vendor_credit_number': '230HO1PR00000101',
#   'tax_override': False,
#   'gst_no': '24AADFJ4292J1Z9',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': 'PK80651',
#   'line_items': [{'item_id': '1357403000004359523',
#     'rate': '435.00',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359523',
#     'rate': '413.25',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 2,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '265.71',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 3,
#     'tax_id': '1357403000000016427'}]},
#  {'date': '2023-05-01',
#   'vendor_id': '1357403000004131286',
#   'vendor_credit_number': '230HO1PR00000100',
#   'tax_override': False,
#   'gst_no': '24AADFM4360N1Z5',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': 'PK82290',
#   'line_items': [{'item_id': '1357403000004357759',
#     'rate': '445.92',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359892',
#     'rate': '144.57',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 2,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359910',
#     'rate': '40.40',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 3,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359910',
#     'rate': '80.80',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 4,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359928',
#     'rate': '154.85',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 5,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360036',
#     'rate': '60.93',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 6,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360135',
#     'rate': '164.29',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 7,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '77.32',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 8,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '169.96',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 9,
#     'tax_id': '1357403000000016427'}]},
#  {'date': '2023-05-01',
#   'vendor_id': '1357403000004131286',
#   'vendor_credit_number': '230HO1PR00000099',
#   'tax_override': False,
#   'gst_no': '24AADFM4360N1Z5',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': 'PK81946',
#   'line_items': [{'item_id': '1357403000004358758',
#     'rate': '2997.82',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360009',
#     'rate': '2683.72',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 2,
#     'tax_id': '1357403000000016427'}]},
#  {'date': '2023-05-01',
#   'vendor_id': '1357403000004131286',
#   'vendor_credit_number': '230HO1PR00000098',
#   'tax_override': False,
#   'gst_no': '24AADFM4360N1Z5',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': 'PK73784',
#   'line_items': [{'item_id': '1357403000004358731',
#     'rate': '268.58',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004358731',
#     'rate': '122.21',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 2,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359523',
#     'rate': '143.57',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 3,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359523',
#     'rate': '399.82',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 4,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360009',
#     'rate': '515.90',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 5,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '1050.53',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 6,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '84.50',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 7,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '203.72',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 8,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '55.73',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 9,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '39.52',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 10,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '149.06',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 11,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '169.00',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 12,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '17.08',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 13,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '611.16',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 14,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '149.06',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 15,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '173.71',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 16,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360762',
#     'rate': '96.61',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 17,
#     'tax_id': '1357403000000016427'}]},
#  {'date': '2023-05-01',
#   'vendor_id': '1357403000004131286',
#   'vendor_credit_number': '230HO1PR00000097',
#   'tax_override': False,
#   'gst_no': '24AADFM4360N1Z5',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': 'PK73589',
#   'line_items': [{'item_id': '1357403000004359523',
#     'rate': '203.13',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359694',
#     'rate': '28.80',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 2,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360009',
#     'rate': '682.22',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 3,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360009',
#     'rate': '335.85',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 4,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360135',
#     'rate': '154.43',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 5,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360135',
#     'rate': '328.58',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 6,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '1258.89',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 7,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '18.57',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 8,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '71.13',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 9,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '244.44',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 10,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '34.54',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 11,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '51.24',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 12,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '479.28',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 13,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '164.86',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 14,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '160.71',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 15,
#     'tax_id': '1357403000000016427'}]},
#  {'date': '2023-05-01',
#   'vendor_id': '1357403000004131286',
#   'vendor_credit_number': '230HO1PR00000096',
#   'tax_override': False,
#   'gst_no': '24AADFM4360N1Z5',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': 'PK81932',
#   'line_items': [{'item_id': '1357403000004357759',
#     'rate': '169.49',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004358731',
#     'rate': '383.46',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 2,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004358731',
#     'rate': '114.88',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 3,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359172',
#     'rate': '68.93',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 4,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360009',
#     'rate': '1759.33',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 5,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '3521.07',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 6,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '75.27',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 7,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '72.94',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 8,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '119.57',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 9,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '203.72',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 10,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '43.21',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 11,
#     'tax_id': '1357403000000016427'}]},
#  {'date': '2023-05-01',
#   'vendor_id': '1357403000004131286',
#   'vendor_credit_number': '230HO1PR00000095',
#   'tax_override': False,
#   'gst_no': '24AADFM4360N1Z5',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': 'PK81760',
#   'line_items': [{'item_id': '1357403000004358731',
#     'rate': '244.42',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '1005.00',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 2,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '526.89',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 3,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360762',
#     'rate': '101.68',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 4,
#     'tax_id': '1357403000000016427'}]},
#  {'date': '2023-05-01',
#   'vendor_id': '1357403000004131286',
#   'vendor_credit_number': '230HO1PR00000094',
#   'tax_override': False,
#   'gst_no': '24AADFM4360N1Z5',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': 'PK81492',
#   'line_items': [{'item_id': '1357403000004358398',
#     'rate': '208.03',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359523',
#     'rate': '139.29',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 2,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359928',
#     'rate': '45.63',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 3,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '70.50',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 4,
#     'tax_id': '1357403000000016427'}]},
#  {'date': '2023-05-01',
#   'vendor_id': '1357403000004131286',
#   'vendor_credit_number': '230HO1PR00000093',
#   'tax_override': False,
#   'gst_no': '24AADFM4360N1Z5',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': 'PK80246',
#   'line_items': [{'item_id': '1357403000004358398',
#     'rate': '289.29',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004358758',
#     'rate': '1056.00',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 2,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359523',
#     'rate': '400.20',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 3,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359928',
#     'rate': '84.54',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 4,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360009',
#     'rate': '169.64',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 5,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360009',
#     'rate': '553.17',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 6,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360036',
#     'rate': '715.64',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 7,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360036',
#     'rate': '658.00',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 8,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360036',
#     'rate': '197.40',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 9,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360036',
#     'rate': '152.86',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 10,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360036',
#     'rate': '91.80',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 11,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360036',
#     'rate': '89.70',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 12,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360036',
#     'rate': '30.60',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 13,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360036',
#     'rate': '63.36',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 14,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360036',
#     'rate': '149.50',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 15,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360180',
#     'rate': '65.64',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 16,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360243',
#     'rate': '844.32',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 17,
#     'tax_id': '1357403000000016427'}]},
#  {'date': '2023-05-01',
#   'vendor_id': '1357403000004131286',
#   'vendor_credit_number': '230HO1PR00000092',
#   'tax_override': False,
#   'gst_no': '24AADFM4360N1Z5',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': 'PK80232',
#   'line_items': [{'item_id': '1357403000004357759',
#     'rate': '533.58',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004357759',
#     'rate': '67.81',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 2,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004358254',
#     'rate': '144.14',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 3,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004358254',
#     'rate': '144.14',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 4,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360009',
#     'rate': '1143.04',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 5,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360009',
#     'rate': '170.86',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 6,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360009',
#     'rate': '519.06',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 7,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360036',
#     'rate': '1769.10',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 8,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360036',
#     'rate': '131.60',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 9,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360036',
#     'rate': '47.25',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 10,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360036',
#     'rate': '65.80',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 11,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360036',
#     'rate': '197.40',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 12,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360036',
#     'rate': '63.00',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 13,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360036',
#     'rate': '189.00',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 14,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360036',
#     'rate': '30.60',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 15,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360036',
#     'rate': '197.40',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 16,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360054',
#     'rate': '187.52',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 17,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '575.42',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 18,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '55.73',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 19,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '112.05',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 20,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '169.00',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 21,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '37.76',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 22,
#     'tax_id': '1357403000000016427'}]},
#  {'date': '2023-05-03',
#   'vendor_id': '1357403000004171798',
#   'vendor_credit_number': '230HO1PR00000109',
#   'tax_override': False,
#   'gst_no': '24AEGFS9849M1Z6',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': '23SZ011097',
#   'line_items': [{'item_id': '1357403000004360315',
#     'rate': '590.93',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016439'}]},
#  {'date': '2023-05-03',
#   'vendor_id': '1357403000004163401',
#   'vendor_credit_number': '230HO1PR00000108',
#   'tax_override': False,
#   'gst_no': '24AUMPP4329F1ZJ',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': '23SZ011474',
#   'line_items': [{'item_id': '1357403000004358794',
#     'rate': '96.52',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016439'}]},
#  {'date': '2023-05-04',
#   'vendor_id': '1357403000004171798',
#   'vendor_credit_number': '230HO1PR00000110',
#   'tax_override': False,
#   'gst_no': '24AEGFS9849M1Z6',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': '23SZ011428',
#   'line_items': [{'item_id': '1357403000004360315',
#     'rate': '642.30',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016439'}]},
#  {'date': '2023-05-05',
#   'vendor_id': '1357403000004185325',
#   'vendor_credit_number': '230HO1PR00000141',
#   'tax_override': False,
#   'gst_no': '24AAJCV1878M1ZP',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': '23SZ012054',
#   'line_items': [{'item_id': '1357403000004358776',
#     'rate': '15884.50',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016433'}]},
#  {'date': '2023-05-05',
#   'vendor_id': '1357403000004122840',
#   'vendor_credit_number': '230HO1PR00000140',
#   'tax_override': False,
#   'gst_no': '24AAIFK7742H1Z7',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': '23SZ011123/23SZ011942',
#   'line_items': [{'item_id': '1357403000004360315',
#     'rate': '1067.70',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016439'},
#    {'item_id': '1357403000004360315',
#     'rate': '444.88',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 2,
#     'tax_id': '1357403000000016439'}]},
#  {'date': '2023-05-05',
#   'vendor_id': '1357403000004122840',
#   'vendor_credit_number': '230HO1PR00000139',
#   'tax_override': False,
#   'gst_no': '24AAIFK7742H1Z7',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': '23SZ012008',
#   'line_items': [{'item_id': '1357403000004358335',
#     'rate': '1064.67',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016439'}]},
#  {'date': '2023-05-05',
#   'vendor_id': '1357403000004121166',
#   'vendor_credit_number': '230HO1PR00000138',
#   'tax_override': False,
#   'gst_no': '24AAAFK9583A1ZI',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': '104060',
#   'line_items': [{'item_id': '1357403000004360018',
#     'rate': '1410.00',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016439'},
#    {'item_id': '1357403000004360018',
#     'rate': '1395.00',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 2,
#     'tax_id': '1357403000000016439'}]},
#  {'date': '2023-05-05',
#   'vendor_id': '1357403000004171798',
#   'vendor_credit_number': '230HO1PR00000137',
#   'tax_override': False,
#   'gst_no': '24AEGFS9849M1Z6',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': '23SZ011804',
#   'line_items': [{'item_id': '1357403000004346032',
#     'rate': '404.80',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016445'}]},
#  {'date': '2023-05-05',
#   'vendor_id': '1357403000004121166',
#   'vendor_credit_number': '230HO1PR00000136',
#   'tax_override': False,
#   'gst_no': '24AAAFK9583A1ZI',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': 'O457',
#   'line_items': [{'item_id': '1357403000004358776',
#     'rate': '404.79',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016433'},
#    {'item_id': '1357403000004359001',
#     'rate': '318.12',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 2,
#     'tax_id': '1357403000000016439'},
#    {'item_id': '1357403000004359235',
#     'rate': '1138.40',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 3,
#     'tax_id': '1357403000000016439'},
#    {'item_id': '1357403000004360315',
#     'rate': '7406.00',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 4,
#     'tax_id': '1357403000000016439'}]},
#  {'date': '2023-05-05',
#   'vendor_id': '1357403000004160053',
#   'vendor_credit_number': '230HO1PR00000135',
#   'tax_override': False,
#   'gst_no': '24AALFS0033N1Z5',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': 'O472',
#   'line_items': [{'item_id': '1357403000004360315',
#     'rate': '2281.30',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016439'}]},
#  {'date': '2023-05-05',
#   'vendor_id': '1357403000004158379',
#   'vendor_credit_number': '230HO1PR00000134',
#   'tax_override': False,
#   'gst_no': '24ABBCS8739H1Z3',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': 'PK92236',
#   'line_items': [{'item_id': '1357403000004358884',
#     'rate': '1369.02',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359388',
#     'rate': '60.00',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 2,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359694',
#     'rate': '48.88',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 3,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359694',
#     'rate': '124.05',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 4,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359910',
#     'rate': '271.96',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 5,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360009',
#     'rate': '957.90',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 6,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360036',
#     'rate': '109.17',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 7,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '183.32',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 8,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '241.34',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 9,
#     'tax_id': '1357403000000016427'}]},
#  {'date': '2023-05-05',
#   'vendor_id': '1357403000004082242',
#   'vendor_credit_number': '230HO1PR00000133',
#   'tax_override': False,
#   'gst_no': '24AAVFA2952N1ZX',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': 'PK92196',
#   'line_items': [{'item_id': '1357403000004360054',
#     'rate': '90.36',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016427'}]},
#  {'date': '2023-05-05',
#   'vendor_id': '1357403000004149857',
#   'vendor_credit_number': '230HO1PR00000132',
#   'tax_override': False,
#   'gst_no': '24AASFP4091N1ZJ',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': 'PK92053',
#   'line_items': [{'item_id': '1357403000004360009',
#     'rate': '510.20',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360162',
#     'rate': '73.60',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 2,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '70.88',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 3,
#     'tax_id': '1357403000000016427'}]},
#  {'date': '2023-05-05',
#   'vendor_id': '1357403000004116117',
#   'vendor_credit_number': '230HO1PR00000131',
#   'tax_override': False,
#   'gst_no': '24AADFJ4292J1Z9',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': 'PK92012',
#   'line_items': [{'item_id': '1357403000004357759',
#     'rate': '268.50',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359388',
#     'rate': '512.13',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 2,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '88.90',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 3,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '174.28',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 4,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '814.29',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 5,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '174.22',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 6,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '635.12',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 7,
#     'tax_id': '1357403000000016427'}]},
#  {'date': '2023-05-05',
#   'vendor_id': '1357403000004121166',
#   'vendor_credit_number': '230HO1PR00000130',
#   'tax_override': False,
#   'gst_no': '24AAAFK9583A1ZI',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': 'PK93472',
#   'line_items': [{'item_id': '1357403000004358344',
#     'rate': '55.71',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004358344',
#     'rate': '55.71',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 2,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359226',
#     'rate': '65.30',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 3,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359226',
#     'rate': '61.88',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 4,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359775',
#     'rate': '478.52',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 5,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359775',
#     'rate': '244.14',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 6,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359775',
#     'rate': '76.50',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 7,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360009',
#     'rate': '981.61',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 8,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360009',
#     'rate': '133.65',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 9,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360009',
#     'rate': '133.65',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 10,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360009',
#     'rate': '154.71',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 11,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360009',
#     'rate': '51.55',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 12,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360009',
#     'rate': '191.28',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 13,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360009',
#     'rate': '51.57',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 14,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360009',
#     'rate': '82.95',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 15,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '1736.52',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 16,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '261.42',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 17,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '267.23',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 18,
#     'tax_id': '1357403000000016427'}]},
#  {'date': '2023-05-05',
#   'vendor_id': '1357403000004121166',
#   'vendor_credit_number': '230HO1PR00000129',
#   'tax_override': False,
#   'gst_no': '24AAAFK9583A1ZI',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': 'PK93484',
#   'line_items': [{'item_id': '1357403000004357633',
#     'rate': '69.40',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004357759',
#     'rate': '134.92',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 2,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359019',
#     'rate': '452.28',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 3,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359019',
#     'rate': '144.34',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 4,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359433',
#     'rate': '46.38',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 5,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359523',
#     'rate': '209.16',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 6,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359523',
#     'rate': '285.51',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 7,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360054',
#     'rate': '312.64',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 8,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '1045.31',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 9,
#     'tax_id': '1357403000000016427'}]},
#  {'date': '2023-05-05',
#   'vendor_id': '1357403000004121166',
#   'vendor_credit_number': '230HO1PR00000128',
#   'tax_override': False,
#   'gst_no': '24AAAFK9583A1ZI',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': 'PK93494',
#   'line_items': [{'item_id': '1357403000004357759',
#     'rate': '149.15',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004357759',
#     'rate': '135.59',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 2,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004357759',
#     'rate': '86.56',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 3,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004358758',
#     'rate': '319.44',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 4,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004358758',
#     'rate': '118.07',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 5,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004358758',
#     'rate': '236.12',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 6,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359199',
#     'rate': '93.54',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 7,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359199',
#     'rate': '34.95',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 8,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359523',
#     'rate': '643.21',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 9,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359775',
#     'rate': '99.92',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 10,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360009',
#     'rate': '98.57',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 11,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360036',
#     'rate': '72.50',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 12,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360036',
#     'rate': '40.77',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 13,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '476.79',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 14,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '331.47',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 15,
#     'tax_id': '1357403000000016427'}]},
#  {'date': '2023-05-05',
#   'vendor_id': '1357403000004121166',
#   'vendor_credit_number': '230HO1PR00000127',
#   'tax_override': False,
#   'gst_no': '24AAAFK9583A1ZI',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': 'PK93276',
#   'line_items': [{'item_id': '1357403000004357759',
#     'rate': '276.94',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004357759',
#     'rate': '145.77',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 2,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004357759',
#     'rate': '348.54',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 3,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359775',
#     'rate': '60.17',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 4,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359775',
#     'rate': '178.62',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 5,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '775.90',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 6,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '282.42',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 7,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '141.22',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 8,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '141.22',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 9,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '310.36',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 10,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '198.00',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 11,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '155.18',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 12,
#     'tax_id': '1357403000000016427'}]},
#  {'date': '2023-05-05',
#   'vendor_id': '1357403000004121166',
#   'vendor_credit_number': '230HO1PR00000126',
#   'tax_override': False,
#   'gst_no': '24AAAFK9583A1ZI',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': 'PK93269',
#   'line_items': [{'item_id': '1357403000004357759',
#     'rate': '1725.70',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004357759',
#     'rate': '145.77',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 2,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004357759',
#     'rate': '874.56',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 3,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004357759',
#     'rate': '406.76',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 4,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004357759',
#     'rate': '92.54',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 5,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004357759',
#     'rate': '305.07',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 6,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004357759',
#     'rate': '429.54',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 7,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004357759',
#     'rate': '111.86',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 8,
#     'tax_id': '1357403000000016427'},
# ...
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 10,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '49.69',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 11,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '49.69',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 12,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '49.69',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 13,
#     'tax_id': '1357403000000016427'}]},
#  {'date': '2023-05-12',
#   'vendor_id': '1357403000004160053',
#   'vendor_credit_number': '230HO1PR00000231',
#   'tax_override': False,
#   'gst_no': '24AALFS0033N1Z5',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': 'PK103650',
#   'line_items': [{'item_id': '1357403000004359172',
#     'rate': '405.59',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360009',
#     'rate': '239.82',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 2,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '346.79',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 3,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '54.05',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 4,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '117.50',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 5,
#     'tax_id': '1357403000000016427'}]},
#  {'date': '2023-05-13',
#   'vendor_id': '1357403000004185325',
#   'vendor_credit_number': '230HO1PR00000276',
#   'tax_override': False,
#   'gst_no': '24AAJCV1878M1ZP',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': '23SZ013875',
#   'line_items': [{'item_id': '1357403000004358209',
#     'rate': '120.25',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016439'}]},
#  {'date': '2023-05-13',
#   'vendor_id': '1357403000004178602',
#   'vendor_credit_number': '230HO1PR00000275',
#   'tax_override': False,
#   'gst_no': '24AAAFU8276A1ZC',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': 'PK82286',
#   'line_items': [{'item_id': '1357403000004357759',
#     'rate': '431.20',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004358020',
#     'rate': '220.00',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 2,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004358020',
#     'rate': '450.00',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 3,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004358758',
#     'rate': '1072.20',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 4,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359694',
#     'rate': '79.32',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 5,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359757',
#     'rate': '383.36',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 6,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359892',
#     'rate': '1598.95',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 7,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359910',
#     'rate': '252.88',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 8,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004359910',
#     'rate': '33.74',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 9,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360135',
#     'rate': '526.78',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 10,
#     'tax_id': '1357403000000016427'},
#    {'item_id': '1357403000004360306',
#     'rate': '500.28',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 11,
#     'tax_id': '1357403000000016427'}]},
#  {'date': '2023-05-15',
#   'vendor_id': '1357403000004121166',
#   'vendor_credit_number': '230HO1PR00000279',
#   'tax_override': False,
#   'gst_no': '24AAAFK9583A1ZI',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': '618822',
#   'line_items': [{'item_id': '1357403000004358794',
#     'rate': '23.80',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016439'}]},
#  {'date': '2023-05-15',
#   'vendor_id': '1357403000004160053',
#   'vendor_credit_number': '230HO1PR00000278',
#   'tax_override': False,
#   'gst_no': '24AALFS0033N1Z5',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': 'O598',
#   'line_items': [{'item_id': '1357403000004360018',
#     'rate': '181.35',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016439'}]},
#  {'date': '2023-05-15',
#   'vendor_id': '1357403000004185325',
#   'vendor_credit_number': '230HO1PR00000277',
#   'tax_override': False,
#   'gst_no': '24AAJCV1878M1ZP',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': '23SZ015559',
#   'line_items': [{'item_id': '1357403000004360315',
#     'rate': '259.36',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016439'}]},
#  {'date': '2023-05-16',
#   'vendor_id': '1357403000004122840',
#   'vendor_credit_number': '230HO1PR00000281',
#   'tax_override': False,
#   'gst_no': '24AAIFK7742H1Z7',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': '23SZ013138',
#   'line_items': [{'item_id': '1357403000004360456',
#     'rate': '7656.00',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016427'}]},
#  {'date': '2023-05-16',
#   'vendor_id': '1357403000004170124',
#   'vendor_credit_number': '230HO1PR00000280',
#   'tax_override': False,
#   'gst_no': '24AAHFS7612P1ZQ',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': '23SZ012632',
#   'line_items': [{'item_id': '1357403000004360315',
#     'rate': '259.08',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016439'}]},
#  {'date': '2023-05-18',
#   'vendor_id': '1357403000004093987',
#   'vendor_credit_number': '230HO1PR00000283',
#   'tax_override': False,
#   'gst_no': '24AAGFM1285R1ZS',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': '23SZ004702',
#   'line_items': [{'item_id': '1357403000004360315',
#     'rate': '626.05',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016439'}]},
#  {'date': '2023-05-18',
#   'vendor_id': '1357403000004163401',
#   'vendor_credit_number': '230HO1PR00000282',
#   'tax_override': False,
#   'gst_no': '24AUMPP4329F1ZJ',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': '23SZ022301',
#   'line_items': [{'item_id': '1357403000004360315',
#     'rate': '315.64',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016439'}]},
#  {'date': '2023-05-19',
#   'vendor_id': '1357403000004121166',
#   'vendor_credit_number': '230HO1PR00000285',
#   'tax_override': False,
#   'gst_no': '24AAAFK9583A1ZI',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': '111860',
#   'line_items': [{'item_id': '1357403000004360126',
#     'rate': '327.20',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016433'}]},
#  {'date': '2023-05-19',
#   'vendor_id': '1357403000004185325',
#   'vendor_credit_number': '230HO1PR00000284',
#   'tax_override': False,
#   'gst_no': '24AAJCV1878M1ZP',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': '23SZ016908',
#   'line_items': [{'item_id': '1357403000004360315',
#     'rate': '907.20',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016439'}]},
#  {'date': '2023-05-20',
#   'vendor_id': '1357403000004171798',
#   'vendor_credit_number': '230HO1PR00000287',
#   'tax_override': False,
#   'gst_no': '24AEGFS9849M1Z6',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': '23SZ014835/23SZ014884',
#   'line_items': [{'item_id': '1357403000004357651',
#     'rate': '513.92',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016445'},
#    {'item_id': '1357403000004358794',
#     'rate': '109.05',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 2,
#     'tax_id': '1357403000000016439'},
#    {'item_id': '1357403000004360315',
#     'rate': '34.08',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 3,
#     'tax_id': '1357403000000016439'},
#    {'item_id': '1357403000004360315',
#     'rate': '225.40',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 4,
#     'tax_id': '1357403000000016439'}]},
#  {'date': '2023-05-20',
#   'vendor_id': '1357403000004121166',
#   'vendor_credit_number': '230HO1PR00000286',
#   'tax_override': False,
#   'gst_no': '24AAAFK9583A1ZI',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': '112639',
#   'line_items': [{'item_id': '1357403000004357624',
#     'rate': '266.06',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016445'}]},
#  {'date': '2023-05-22',
#   'vendor_id': '1357403000004105894',
#   'vendor_credit_number': '230HO1PR00000289',
#   'tax_override': False,
#   'gst_no': '24BKJPM9183L1ZH',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': '1234',
#   'line_items': [{'item_id': '1357403000004360447',
#     'rate': '12.60',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016439'}]},
#  {'date': '2023-05-22',
#   'vendor_id': '1357403000004160053',
#   'vendor_credit_number': '230HO1PR00000288',
#   'tax_override': False,
#   'gst_no': '24AALFS0033N1Z5',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': '0670',
#   'line_items': [{'item_id': '1357403000004360315',
#     'rate': '60.78',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016439'}]},
#  {'date': '2023-05-23',
#   'vendor_id': '1357403000004093987',
#   'vendor_credit_number': '230HO1PR00000290',
#   'tax_override': False,
#   'gst_no': '24AAGFM1285R1ZS',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': '23SZ005122',
#   'line_items': [{'item_id': '1357403000004359109',
#     'rate': '236.54',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016439'}]},
#  {'date': '2023-05-24',
#   'vendor_id': '1357403000004160053',
#   'vendor_credit_number': '230HO1PR00000291',
#   'tax_override': False,
#   'gst_no': '24AALFS0033N1Z5',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': 'O697',
#   'line_items': [{'item_id': '1357403000004359235',
#     'rate': '110.73',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016439'}]},
#  {'date': '2023-05-26',
#   'vendor_id': '1357403000004129612',
#   'vendor_credit_number': '230HO1PR00000293',
#   'tax_override': False,
#   'gst_no': '24AAIFM6975E1Z2',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': 'MRG2213393',
#   'line_items': [{'item_id': '1357403000004360018',
#     'rate': '2121.50',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016439'}]},
#  {'date': '2023-05-26',
#   'vendor_id': '1357403000004160053',
#   'vendor_credit_number': '230HO1PR00000292',
#   'tax_override': False,
#   'gst_no': '24AALFS0033N1Z5',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': 'O723 / O724',
#   'line_items': [{'item_id': '1357403000004357651',
#     'rate': '233.90',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016445'},
#    {'item_id': '1357403000004359874',
#     'rate': '130.73',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 2,
#     'tax_id': '1357403000000016439'}]},
#  {'date': '2023-05-27',
#   'vendor_id': '1357403000004093987',
#   'vendor_credit_number': '230HO1PR00000295',
#   'tax_override': False,
#   'gst_no': '24AAGFM1285R1ZS',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': '23SZ005590',
#   'line_items': [{'item_id': '1357403000004359109',
#     'rate': '236.54',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016439'}]},
#  {'date': '2023-05-27',
#   'vendor_id': '1357403000004160053',
#   'vendor_credit_number': '230HO1PR00000294',
#   'tax_override': False,
#   'gst_no': '24AALFS0033N1Z5',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': 'O730',
#   'line_items': [{'item_id': '1357403000004360063',
#     'rate': '92.80',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016439'}]},
#  {'date': '2023-05-31',
#   'vendor_id': '1357403000004121166',
#   'vendor_credit_number': '230HO1PR00000298',
#   'tax_override': False,
#   'gst_no': '24AAAFK9583A1ZI',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': '1234',
#   'line_items': [{'item_id': '1357403000004359235',
#     'rate': '1760.00',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016439'}]},
#  {'date': '2023-05-31',
#   'vendor_id': '1357403000004121166',
#   'vendor_credit_number': '230HO1PR00000297',
#   'tax_override': False,
#   'gst_no': '24AAAFK9583A1ZI',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': '1234',
#   'line_items': [{'item_id': '1357403000004359235',
#     'rate': '10340.00',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016439'},
#    {'item_id': '1357403000004359235',
#     'rate': '12408.00',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 2,
#     'tax_id': '1357403000000016439'},
#    {'item_id': '1357403000004359235',
#     'rate': '8272.00',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 3,
#     'tax_id': '1357403000000016439'},
#    {'item_id': '1357403000004359235',
#     'rate': '220.00',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 4,
#     'tax_id': '1357403000000016439'},
#    {'item_id': '1357403000004359235',
#     'rate': '4857.60',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 5,
#     'tax_id': '1357403000000016439'}]},
#  {'date': '2023-05-31',
#   'vendor_id': '1357403000004121166',
#   'vendor_credit_number': '230HO1PR00000296',
#   'tax_override': False,
#   'gst_no': '24AAAFK9583A1ZI',
#   'is_inclusive_tax': False,
#   'reference_invoice_type': 'registered',
#   'reference_number': '619263',
#   'line_items': [{'item_id': '1357403000004360018',
#     'rate': '100.20',
#     'itc_eligibility': 'eligible',
#     'quantity': '1',
#     'item_order': 1,
#     'tax_id': '1357403000000016439'}]}]

# %%
import requests
import json
url = "https://www.zohoapis.in/books/v3/vendorcredits?organization_id=60022053195"
headers = {
  'Content-Type': 'application/json',
  'Authorization': 'Zoho-oauthtoken 1000.486b579fc80b8f43ae298fa18881863a.24e37dc51d0a48da1235a655ca0f86df'
}
failedData = []
for data in null_voucher_dict:
    payload = json.dumps(data)


    response = requests.request("POST", url, headers=headers, data=payload)
    if response.status_code >= 200 and response.status_code < 300:  # Assuming a successful response has a status code of 200
        data = response.json()
        # Process the response data as needed
        # print(data)
    else:

        print(f"API request failed with status code {response.status_code}")
        response_content = response.content.decode('utf-8')
        failedData.append(data['vendor_credit_number'])
        print(response_content)

print("__________________________________")
print("Finished")
print("__________________________________")
print("failed records bill number : ")
print(failedData)
# Out:
# __________________________________
# Finished
# __________________________________
# failed records bill number :
# []
